# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv("/content/Agrofood_co2_emission.csv")

# %%
df.head()
# Out:
#           Area  Year  Savanna fires  Forest fires  Crop Residues  \
# 0  Afghanistan  1990        14.7237        0.0557       205.6077
# 1  Afghanistan  1991        14.7237        0.0557       209.4971
# 2  Afghanistan  1992        14.7237        0.0557       196.5341
# 3  Afghanistan  1993        14.7237        0.0557       230.8175
# 4  Afghanistan  1994        14.7237        0.0557       242.0494
#
#    Rice Cultivation  Drained organic soils (CO2)  Pesticides Manufacturing  \
# 0            686.00                          0.0                 11.807483
# 1            678.16                          0.0                 11.712073
# 2            686.00                          0.0                 11.712073
# 3            686.00                          0.0                 11.712073
# 4            705.60                          0.0                 11.712073
#
#    Food Transport  Forestland  ...  Manure Management  Fires in organic soils  \
# ...

# %%
df.dropna()
# Out:
#           Area  Year  Savanna fires  Forest fires  Crop Residues  \
# 31     Albania  1990         5.5561        7.0253        59.2391
# 32     Albania  1991         5.5561        7.0253        31.4625
# 33     Albania  1992         5.5561        7.0253        29.9373
# 34     Albania  1993         5.5561        7.0253        44.0550
# 35     Albania  1994         5.5561        7.0253        42.4253
# ...        ...   ...            ...           ...            ...
# 6960  Zimbabwe  2016      1190.0089      232.5068        70.9451
# 6961  Zimbabwe  2017      1431.1407      131.1324       108.6262
# 6962  Zimbabwe  2018      1557.5830      221.6222       109.9835
# 6963  Zimbabwe  2019      1591.6049      171.0262        45.4574
# 6964  Zimbabwe  2020       481.9027       48.4197       108.3022
#
#       Rice Cultivation  Drained organic soils (CO2)  Pesticides Manufacturing  \
# 31             23.5200                     110.5705                       2.0
# ...

# %%
df.drop(columns=["Savanna fires","Total Population - Female","Total Population - Male","Area","Year","Food Transport","Fires in humid tropical forests"],inplace=True)

# %%
df.head()
# Out:
#    Forest fires  Crop Residues  Rice Cultivation  Drained organic soils (CO2)  \
# 0        0.0557       205.6077            686.00                          0.0
# 1        0.0557       209.4971            678.16                          0.0
# 2        0.0557       196.5341            686.00                          0.0
# 3        0.0557       230.8175            686.00                          0.0
# 4        0.0557       242.0494            705.60                          0.0
#
#    Pesticides Manufacturing  Forestland  Net Forest conversion  \
# 0                 11.807483   -2388.803                    0.0
# 1                 11.712073   -2388.803                    0.0
# 2                 11.712073   -2388.803                    0.0
# 3                 11.712073   -2388.803                    0.0
# 4                 11.712073   -2388.803                    0.0
#
#    Food Household Consumption  Food Retail  On-farm Electricity Use  ...  \
# ...

# %%
df.drop(columns=["IPPU","Drained organic soils (CO2)"],inplace=True)

# %%
df.head()
# Out:
#    Forest fires  Crop Residues  Rice Cultivation  Pesticides Manufacturing  \
# 0        0.0557       205.6077            686.00                 11.807483
# 1        0.0557       209.4971            678.16                 11.712073
# 2        0.0557       196.5341            686.00                 11.712073
# 3        0.0557       230.8175            686.00                 11.712073
# 4        0.0557       242.0494            705.60                 11.712073
#
#    Forestland  Net Forest conversion  Food Household Consumption  Food Retail  \
# 0   -2388.803                    0.0                     79.0851     109.6446
# 1   -2388.803                    0.0                     80.4885     116.6789
# 2   -2388.803                    0.0                     80.7692     126.1721
# 3   -2388.803                    0.0                     85.0678      81.4607
# 4   -2388.803                    0.0                     88.8058      90.4008
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6965 entries, 0 to 6964
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Forest fires                     6872 non-null   float64
#  1   Crop Residues                    5576 non-null   float64
#  2   Rice Cultivation                 6965 non-null   float64
#  3   Pesticides Manufacturing         6965 non-null   float64
#  4   Forestland                       6472 non-null   float64
#  5   Net Forest conversion            6472 non-null   float64
#  6   Food Household Consumption       6492 non-null   float64
#  7   Food Retail                      6965 non-null   float64
#  8   On-farm Electricity Use          6965 non-null   float64
#  9   Food Packaging                   6965 non-null   float64
#  10  Agrifood Systems Waste Disposal  6965 non-null   float64
# ...

# %%
df.drop(columns=["Forestland","Net Forest conversion"],inplace=True)

# %%
df.isnull().sum()
# Out:
# Forest fires                         93
# Crop Residues                      1389
# Rice Cultivation                      0
# Pesticides Manufacturing              0
# Food Household Consumption          473
# Food Retail                           0
# On-farm Electricity Use               0
# Food Packaging                        0
# Agrifood Systems Waste Disposal       0
# Food Processing                       0
# Fertilizers Manufacturing             0
# Manure applied to Soils             928
# Manure left on Pasture                0
# Manure Management                   928
# Fires in organic soils                0
# On-farm energy use                  956
# Rural population                      0
# Urban population                      0
# total_emission                        0
# Average Temperature °C                0
# dtype: int64

# %%
df['Crop Residues'].fillna(df['Crop Residues'].mean(), inplace=True)
# Out:
# <ipython-input-12-8c44a84f4373>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Crop Residues'].fillna(df['Crop Residues'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Forest fires                        93
# Crop Residues                        0
# Rice Cultivation                     0
# Pesticides Manufacturing             0
# Food Household Consumption         473
# Food Retail                          0
# On-farm Electricity Use              0
# Food Packaging                       0
# Agrifood Systems Waste Disposal      0
# Food Processing                      0
# Fertilizers Manufacturing            0
# Manure applied to Soils            928
# Manure left on Pasture               0
# Manure Management                  928
# Fires in organic soils               0
# On-farm energy use                 956
# Rural population                     0
# Urban population                     0
# total_emission                       0
# Average Temperature °C               0
# dtype: int64

# %%
df['Forest fires'].fillna(df['Forest fires'].mean(), inplace=True)
# Out:
# <ipython-input-14-be5dd62980fa>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Forest fires'].fillna(df['Forest fires'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Forest fires                         0
# Crop Residues                        0
# Rice Cultivation                     0
# Pesticides Manufacturing             0
# Food Household Consumption         473
# Food Retail                          0
# On-farm Electricity Use              0
# Food Packaging                       0
# Agrifood Systems Waste Disposal      0
# Food Processing                      0
# Fertilizers Manufacturing            0
# Manure applied to Soils            928
# Manure left on Pasture               0
# Manure Management                  928
# Fires in organic soils               0
# On-farm energy use                 956
# Rural population                     0
# Urban population                     0
# total_emission                       0
# Average Temperature °C               0
# dtype: int64

# %%
df.drop(columns=["Food Household Consumption","Manure applied to Soils","Manure left on Pasture","Food Packaging"],inplace=True)

# %%
df['On-farm energy use'].fillna(df['On-farm energy use'].mean(), inplace=True)
# Out:
# <ipython-input-17-9f95607f1ab2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['On-farm energy use'].fillna(df['On-farm energy use'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Forest fires                         0
# Crop Residues                        0
# Rice Cultivation                     0
# Pesticides Manufacturing             0
# Food Retail                          0
# On-farm Electricity Use              0
# Agrifood Systems Waste Disposal      0
# Food Processing                      0
# Fertilizers Manufacturing            0
# Manure Management                  928
# Fires in organic soils               0
# On-farm energy use                   0
# Rural population                     0
# Urban population                     0
# total_emission                       0
# Average Temperature °C               0
# dtype: int64

# %%
df.drop(columns=["Manure Management"],inplace=True)

# %%
df.isnull().sum()
# Out:
# Forest fires                       0
# Crop Residues                      0
# Rice Cultivation                   0
# Pesticides Manufacturing           0
# Food Retail                        0
# On-farm Electricity Use            0
# Agrifood Systems Waste Disposal    0
# Food Processing                    0
# Fertilizers Manufacturing          0
# Fires in organic soils             0
# On-farm energy use                 0
# Rural population                   0
# Urban population                   0
# total_emission                     0
# Average Temperature °C             0
# dtype: int64

# %%
df.describe()
# Out:
#        Forest fires  Crop Residues  Rice Cultivation  \
# count   6965.000000    6965.000000       6965.000000
# mean     919.302167     998.706309       4259.666673
# std     3695.155566    3310.818022      17613.825187
# min        0.000000       0.000200          0.000000
# 25%        0.000000      25.360100        181.260800
# 50%        0.646500     193.083100        534.817400
# 75%       78.057200     998.706309       1536.640000
# max    52227.630600   33490.074100     164915.255600
#
#        Pesticides Manufacturing    Food Retail  On-farm Electricity Use  \
# count               6965.000000    6965.000000              6965.000000
# mean                 333.418393    2043.210539              1626.681460
# std                 1429.159367    8494.249260              9343.182193
# min                    0.000000       0.000000                 0.000000
# 25%                    6.000000      26.818500                 8.037600
# ...

# %%
df.head()
# Out:
#    Forest fires  Crop Residues  Rice Cultivation  Pesticides Manufacturing  \
# 0        0.0557       205.6077            686.00                 11.807483
# 1        0.0557       209.4971            678.16                 11.712073
# 2        0.0557       196.5341            686.00                 11.712073
# 3        0.0557       230.8175            686.00                 11.712073
# 4        0.0557       242.0494            705.60                 11.712073
#
#    Food Retail  On-farm Electricity Use  Agrifood Systems Waste Disposal  \
# 0     109.6446                  14.2666                         691.7888
# 1     116.6789                  11.4182                         710.8212
# 2     126.1721                   9.2752                         743.6751
# 3      81.4607                   9.0635                         791.9246
# 4      90.4008                   8.3962                         831.9181
#
#    Food Processing  Fertilizers Manufacturing  Fires in organic soils  \
# ...

# %%
x = df.drop(columns=["total_emission"])
y = df["total_emission"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[ 9.59471368e+00, -2.57335101e-01, -2.21927624e-01, ...,
#          1.26962856e-01, -2.20313278e-02,  1.85773864e-01],
#        [-2.44937416e-01, -2.96608073e-01, -2.25057765e-01, ...,
#         -1.79598177e-01, -2.41841789e-01,  1.05342644e-01],
#        [-2.44208506e-01,  1.19459115e-01, -2.05556232e-01, ...,
#         -1.14777816e-01, -1.03723613e-01,  1.94822109e+00],
#        ...,
#        [-2.44646064e-01,  5.96902405e-02, -2.34469747e-01, ...,
#         -9.70232413e-02, -9.40455467e-02,  1.39284127e+00],
#        [-2.45228014e-01, -9.66378342e-04, -8.93770215e-02, ...,
#         -1.98618386e-01, -2.63605537e-01, -2.49781303e+00],
#        [-2.45225025e-01, -9.66378342e-04, -9.58573570e-02, ...,
#         -1.98513146e-01, -2.63595814e-01, -8.26730873e-01]])

# %%
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

# Impute missing values with the mean
imputer = SimpleImputer(strategy='mean')

# Create a pipeline
model = make_pipeline(imputer, LinearRegression())

# Fit the model
model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('linearregression', LinearRegression())])

# %%
ypred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(y_test,ypred)
mse
# Out:
# 3646037523.3602595

# %%
y_test
# Out:
# 1335      9797.212910
# 5679      7787.792976
# 5962    101066.468635
# 37        3231.956747
# 5939     10488.420496
#             ...
# 533       1793.663214
# 2375      7402.102213
# 2184     14188.460658
# 652      21904.469472
# 33        5221.131572
# Name: total_emission, Length: 1393, dtype: float64

# %%
r2=r2_score(y_test,ypred)
r2
# Out:
# 0.9472914536227651

# %%
import pickle

# %%
with open('Project.pkl', 'wb') as file:
    pickle.dump(model, file)
